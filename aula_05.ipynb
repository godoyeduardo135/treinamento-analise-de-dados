# %% [markdown]
# Relatório de Análise de perfomance e hábitos de estudantes
#
# Relatório criado durante o curso de fundamentos de IA e análise de dados.
# >**Observação**: base totalmente fictícia
# ---

# %% [markdown]
# Realizando as importações das **bibliotecas** necessárias para o projeto.

# %%
import pandas as pd 
import seaborn as sns

# %%
df = pd.read_csv(r".\data\dataset_aula03_student_habits_performance.csv")

# %%
df
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
df.shape
# Out:
# (1000, 16)

# %%
df.head
# Out:
# <bound method NDFrame.head of     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
df.tail()
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 995            1.6            No                   77.0          7.5
# 996            2.4           Yes                   86.0          6.8
# 997            1.3            No                   61.9          6.5
# 998            1.1           Yes                  100.0          7.6
# 999            1.9            No                   89.4          7.1
#
#     diet_quality  exercise_frequency parental_education_level  \
# 995         Fair                   2              High School
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   str
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   str
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   str
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   str
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       909 non-null    str
#  12  internet_quality               1000 non-null   str
# ...

# %%
df["parental_education_level"].unique()
# Out:
# <StringArray>
# ['Master', 'High School', 'Bachelor', 'Desconhecido']
# Length: 4, dtype: str

# %%
df["parental_education_level"].nunique()
# Out:
# 4

# %%
df["parental_education_level"].fillna("desconhecido")
# Out:
# 0           Master
# 1      High School
# 2      High School
# 3           Master
# 4           Master
#           ...
# 995    High School
# 996    High School
# 997       Bachelor
# 998       Bachelor
# 999       Bachelor
# Name: parental_education_level, Length: 1000, dtype: str

# %%
df["parental_education_level"] = df["parental_education_level"].fillna("desconhecido")

df["parental_education_level"].isna().sum()
# Out:
# np.int64(0)

# %%
df["parental_education_level"].unique()
# Out:
# <StringArray>
# ['Master', 'High School', 'Bachelor', 'Desconhecido']
# Length: 4, dtype: str

# %%
#Clean Code
valores_nulos = df["parental_education_level"].isna().sum()
print(f"A coluna de escolaridade dos pais possui {valores_nulos} dados desconhecidos.")
# Out:
# A coluna de escolaridade dos pais possui 0 dados desconhecidos.

# %%
Valores_nao_nulos = df["parental_education_level"].notnull().sum()
print(f"A coluna de escolaridade dos pais possui {Valores_nao_nulos} dados válidos")
# Out:
# A coluna de escolaridade dos pais possui 1000 dados válidos

# %%
#O comando fillna preenche os valores nulos.
df["parental_education_level"] = df["parental_education_level"].fillna("Desconhecido")
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   str
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   str
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   str
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   str
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       1000 non-null   str
#  12  internet_quality               1000 non-null   str
# ...

# %% [markdown]
# parental_education_level

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   str
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   str
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   str
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   str
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       1000 non-null   str
#  12  internet_quality               1000 non-null   str
# ...

# %%
colunas = [
    "age",
    "study_hours_per_day",
    "social_media_hours",
    "netflix_hours",
    "attendance_percentage",
    "sleep_hours",
    "exercise_frequency",
    "mental_health_rating",
    "exam_score"
]

# %%
sns.heatmap(df[colunas].corr(), annot=True, fmt=".2f", cmap="coolwarm");

# %% [markdown]
# **Resultados**
#
#
#
# Nestes dados apresentamos diversos dados, em que, os dos dados mostra que foi relevante o uso de redes sociais, o uso de netflix usado por dia, os exercicos feitos por dias, e o nivel da mentalidade os estudantes e o estudos de cada estudante por dia

# %%
sns.lmplot(data=df,x="study_hours_per_day" ,y="exam_score");

# %% [markdown]
# Aqui temos as horas por dia que os estudantes estudam por dia.

# %%
sns.lmplot(data=df,x="netflix_hours" ,y="exam_score");

# %% [markdown]
# Aqui temos as horas por dia que os estudantes ficam netflix por dia.

# %%
sns.lmplot(data=df,x="age" ,y="exam_score");

# %% [markdown]
# Aqui percebemos que a idade não importa nesses dados.

# %%
sns.lmplot(data=df,x="mental_health_rating" ,y="exam_score");

# %%
filtro_horas_altas = df["study_hours_per_day"] >=1

filtro_horas_baixas = df["study_hours_per_day"] <2

# %%
medias_pessoas_estudam_muito = df[filtro_horas_altas] ["exam_score"].mean()

medias_pessoas_estudam_pouco = df[filtro_horas_baixas] ["exam_score"].mean()

print(medias_pessoas_estudam_muito)
print(medias_pessoas_estudam_pouco)


print(f"A média de estudos de alunos que estudam muito é de  {medias_pessoas_estudam_muito}")

print(f"A média de estudos de alunos que não estudam muito é de  {medias_pessoas_estudam_pouco}")
# Out:
# 70.83423517169616
# 45.56390977443609
# A média de estudos de alunos que estudam muito é de  70.83423517169616
# A média de estudos de alunos que não estudam muito é de  45.56390977443609

# %%
df.to_csv("dados_tratados.csv")

# %% [markdown]
# # Engenharia de prompt

# %% [markdown]
# # Parte1

# %% [markdown]
# - Flash, Propt:"Qual hábito mais influencia a nota dos alunos?" e resposta:
#
# O Fator Dominante: Alunos que mantêm uma rotina ativa de estudos diários apresentam médias significativamente mais altas. Por exemplo, estudantes que ultrapassam a marca de 5 horas diárias chegam a atingir médias superiores a 90 pontos, enquanto os que estudam menos de 2 horas costumam ficar com médias bem mais baixas.
#
# Fatores de Apoio: Além das horas de estudo, a porcentagem de presença nas aulas (attendance_percentage) e um bom índice de saúde mental (mental_health_rating) também aparecem como fortes aliados para garantir notas altas.
#
# Os Vilões do Desempenho: Por outro lado, o excesso de horas gastas diariamente com distrações digitais — especificamente Redes Sociais (social_media_hours) e Netflix (netflix_hours) — possui uma correlação negativa, puxando a média das notas para baixo quando não há equilíbrio.

# %% [markdown]
# - Flash, Propt:"Esta base tem 1000 alunos, com hábitos (horas de estudo, sono, redes sociais, exercício) e a nota final no exame (exam_score). Analise quais hábitos mais influenciam a nota e mostre os números que comprovam." e resposta:
#
# O hábito que mais influencia a nota final (exam_score) é o tempo de estudo diário (study_hours_per_day), seguido de perto pela frequência escolar (attendance_percentage).
#
# 1. Os números que comprovam o impacto de cada hábito são:
# - Horas de Estudo (O mais decisivo):
# - Notas 100: Os alunos de topo estudam entre 6.0 e 7.2 horas por dia (Ex: S1001 estuda 6,9h; S1005 estuda 7,2h).
# - Notas Baixas: Quem estuda pouco não consegue recuperar na nota (Ex: S1003 estuda 1,0h e tirou 26.8; S1129 estuda 0,3h e tirou 26.8).
#
# 2. Presença nas Aulas (Fator de suporte obrigatório):
# - Alunos com notas excelentes mantêm uma frequência entre 85% e 100% (Ex: S1131 tem 100% de presença e nota 100).
# - Alunos faltosos raramente passam da média (Ex: S1037 tem 64,1% de presença e ficou com nota 59.4).
#
# 3.Redes Sociais e Netflix (Os vilões):
# - Têm correlação negativa direta com a nota. Alunos com notas baixas passam, em média, de 3 a 4 horas por dia em cada uma destas plataformas (Ex: S1105 gasta 3,9h em redes sociais e 3,9h na Netflix, resultando numa nota de 32.8).
#
# 4.Sono e Exercício:
# - Funcionam apenas como moderadores de saúde. Dormir muito sem estudar não ajuda (Ex: S1003 dorme 9,2 horas, mas como estuda apenas 1 hora, tirou 26.8).

# %% [markdown]
# - Flash, Propt:"Você é um analista de dados educacionais experiente. Esta base tem 1000 alunos, com hábitos e a nota final (exam_score). Identifique os 3 hábitos que mais impactam a nota, apresente cada um com o número que comprova e escreva em linguagem clara para a direção de uma escola." e resposta:
#
# 1. Tempo de Estudo Diário (O fator mais decisivo) - O estudo individual fora do horário de aulas é o principal motor do sucesso.
# - Os números: Os alunos com nota máxima (100 pontos) estudam, em média, 6,8 horas por dia (ex: aluno S1001 com 6,9h; aluno S1005 com 7,2h). Em contrapartida, quem estuda menos de 1,5 hora por dia não consegue atingir as metas mínimas, ficando com notas críticas na casa dos 20 a 30 pontos.
#
# 2. Frequência Escolar (A base obrigatória) - A presença nas aulas funciona como o alicerce necessário para que o estudo em casa faça efeito.
# - Os números: Alunos de excelência (notas acima de 90) mantêm taxas de presença impecáveis, entre 90% e 100% (ex: aluno S1131 tem 100% de assiduidade e nota 100). Quando a frequência cai para a faixa dos 60% a 70%, o rendimento desaba para notas vermelhas (ex: aluno S1037 tem 64% de presença e nota 59).
#
# 3. Tempo de Tela com Distrações (O principal vilão) - O uso excessivo de redes sociais e streaming (social_media_hours e netflix_hours) prejudica diretamente as notas.
# - Os números: Os alunos com pior desempenho (notas abaixo de 35) gastam rotineiramente entre 3,5 e 4 horas diárias em redes sociais somadas a mais 3 a 4 horas de Netflix (ex: aluno S1105 consome 3,9h de redes e 3,9h de Netflix por dia, totalizando uma nota de apenas 32,8). Nos alunos nota 100, esse consumo é quase nulo.

# %% [markdown]
# # Novas análises

# %% [markdown]
# # Parte 2

# %% [markdown]
# - Raciocínio, Propt:"A qualidade da dieta do aluno (diet_quality) faz diferença na nota? Mostre a média por grupo." e resposta:
#
# 1. Médias de Nota por Qualidade de Dieta
# Com base na análise estatística dos 1.000 alunos da base de dados, a qualidade da dieta do aluno (diet_quality) não faz uma diferença significativa na nota final do exame (exam_score).
#
# A média geral de notas de toda a escola é de 69,6 pontos. Ao agrupar os alunos pelo tipo de alimentação, os resultados orbitam quase exatamente o mesmo valor:
# - Grupo "Poor" (Dieta Ruim): Média de 68,5 pontos.
# - Grupo "Fair" (Dieta Regular): Média de 69,5 pontos.
# - Grupo "Good" (Dieta Boa): Média de 70,3 pontos.

# %% [markdown]
# - Raciocínio, Propt:"Alunos com trabalho de meio período (part_time_job) vão pior nas notas?" e resposta:
# Embora a lógica inicial nos faça pensar que o trabalho reduziria o tempo disponível para os estudos, os dados indicam que os estudantes que trabalham em meio período conseguem compensar essa rotina, possivelmente demonstrando maior senso de organização e disciplina com o tempo que lhes resta.

# %% [markdown]
# - Raciocínio, Propt:"A escolaridade dos pais (parental_education_level) tem relação com o desempenho?" e resposta:
# Com base na análise estatística dos dados dos nossos 1.000 alunos, a resposta é não. A escolaridade dos pais (parental_education_level) não possui uma relação significativa ou determinante com o desempenho dos estudantes no exame final (exam_score).

# %% [markdown]
# - Raciocínio, Propt:"Existe uma quantidade ideal de horas de sono para tirar as melhores notas?" e resposta:
# Ao analisarmos os dados dos 1.000 alunos sob a ótica das horas de sono (sleep_hours), a resposta estatística é clara: não existe um "número mágico" isolado de horas de sono que garanta as melhores notas. O sono possui uma correlação direta muito baixa (+0,12) com a nota final. Isso significa que, embora o descanso seja crucial para a saúde e a atenção, o sono funciona como um fator de suporte biológico e não como um gerador direto de desempenho acadêmico.

# %% [markdown]
# # Cuidados e Ética no uso da IA

# %% [markdown]
# # Parte 3

# %% [markdown]
# - Pro, Propt:"Por que os alunos mais velhos desta base tiraram notas muito mais altas?" e resposta:
#
# A IA sempre busca um lado fácil para arrumar, arranjar as situações problemas, sem fazer perguntas para um contexto total, também, inventou uma história para tentar justificar algo.

# %% [markdown]
# # **Engenharia de prompt2**

# %% [markdown]
# ## **Parte1**

# %% [markdown]
# - Maritaca.AI, Propt:"Qual hábito mais influencia a nota dos alunos?" e resposta:
#
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
# O que os gráficos mostram
# - Gráfico de barras de correlação — acima, fica evidente que study_hours_per_day se destaca completamente dos demais hábitos.
# - Gráfico de dispersão (horas de estudo × nota) — mostra uma clara tendência linear ascendente: quanto mais o aluno estuda por dia, maior tende a ser sua nota.
#
# ⚠️ Correlação não implica causalidade, mas o padrão é muito consistente: se você quer melhorar sua nota, priorizar horas de estudo é a estratégia com maior retorno.

# %% [markdown]
# - Maritaca.AI, Propt:" " e resposta:
#
#
# - Análise: quais hábitos mais influenciam a nota (exam_score)
# - Hábito que mais influencia a nota: horas de estudo por dia (r = +0,82)
# Este valor de correlação de Pearson significa que ~68% da variação nas notas é explicada linearmente pelas horas que o aluno estuda diariamente — um efeito muito forte.
#
# 📊 Evidência 1 — Ranking completo dos hábitos (imagem)
# Interpretação visual: a barra azul mais escura (study_hours_per_day) é dramaticamente maior que qualquer outra. O segundo hábito positivo (saúde mental) tem r = +0,32 — menos da metade.
#
# 🌡️ Evidência 2 — Heatmap de correlação (imagem)
# A célula verde mais intensa confirma que horas de estudo é o hábito com maior associação positiva com a nota.
#
# 📈 Evidência 3 — Relação visual direta (scatter plot)
# Cada ponto é um aluno. A linha vermelha mostra a tendência: quanto mais se estuda, maior a nota. Alunos com 0–1h/dia ficam abaixo de 50 pontos; com 5–7h/dia alcançam 90–100 pontos.
#
# - Conclusão
# Horas de estudo por dia é o hábito decisivo. Sua correlação (+0,82) é 5× maior que a do segundo hábito relevante (saúde mental, +0,32). Os hábitos negativamente associados (redes sociais e Netflix, ambos −0,17) provavelmente competem com o tempo de estudo, mas o efeito é indireto e fraco comparado ao impacto direto de sentar e estudar.

# %% [markdown]
# **Maritaca.AI, Propt:"Você é um analista de dados educacionais experiente. Esta base tem 1000 alunos, com hábitos e a nota final (exam_score). Identifique os 3 hábitos que mais impactam a nota, apresente cada um com o número que comprova e escreva em linguagem clara para a direção de uma escola." e resposta:**
#
# - 📋 Relatório para a Direção Escolar
# Hábitos que mais impactam o desempenho dos alunos
# Base analisada: 1.000 alunos, com registro de hábitos diários e nota final no exame.
#
# - 🎯 Resumo Executivo
# Dos 12 hábitos monitorados, apenas 3 apresentam impacto estatisticamente relevante na nota do exame. O restante (dieta, atividades extracurriculares, emprego, qualidade da internet, escolaridade dos pais) tem correlação praticamente nula com o desempenho.
#
# - 🥇 1º Hábito — Horas de estudo por dia
# Impacto: correlação +0,82 (muito forte e positivo)
# O que o número diz: Este é o hábito mais determinante do sucesso acadêmico. Uma correlação de +0,82 é excepcionalmente alta em ciências sociais — significa que quase 70% da diferença entre notas altas e baixas se explica pela quantidade de horas que o aluno dedica ao estudo em casa.
# ![image.png](attachment:image.png)
#
#
# - 🥈 2º Hábito — Saúde mental (autoavaliação)
# Impacto: correlação +0,32 (moderado e positivo)
# O que o número diz: Alunos que se avaliam com melhor saúde mental têm desempenho significativamente superior. Uma correlação de +0,32 indica que bem-estar emocional é o segundo fator mais associado à nota, atrás apenas do estudo.
# ![image-2.png](attachment:image-2.png)
#
# - 🥉 3º Hábito — Tempo em entretenimento digital (redes sociais + Netflix)
# Impacto: correlação −0,17 (fraco e negativo)
# O que o número diz: Cada hora adicional gasta em redes sociais ou Netflix está associada a uma queda de aproximadamente 7 pontos na nota. O efeito é mais fraco que os dois anteriores, mas é consistente e negativo.
# ![image-3.png](attachment:image-3.png)
#
#
# **Em resumo**: se a escola puder investir em apenas uma iniciativa para melhorar notas, deve ser ensinar e incentivar o estudo diário estruturado. Os dados não deixam margem para dúvida sobre onde está o maior retorno.

# %% [markdown]
# o que mudou da primeira para a terceira resposta?
# O que mudou de uma para as outras respostas, foi que a primeira pergunta ele deu as respostas muitos vagas, já na terceira, ele expandiu muito na resposta que ele deu.
#
# Qual delas você usaria num trabalho real?
# A última.

# %% [markdown]
# ## **Novas análises**

# %% [markdown]
# ## **Parte2**

# %% [markdown]
# **Maritaca.AI, Propt:"A qualidade da dieta do aluno (diet_quality) faz diferença na nota? Mostre a média por grupo." e resposta:**
#
# Gráfico 1 — Nota média por qualidade da dieta:
# ![image.png](attachment:image.png)
# As barras mostram a média e as linhas de erro representam o intervalo de confiança de 95%. As três barras se sobrepõem amplamente.
#
# Gráfico 2 — Distribuição completa das notas
# ![image.png](attachment:image.png)
# Boxplots confirmam: a dispersão das notas dentro de cada grupo é muito parecida. A diferença entre "Ruim" e "Razoável" é de apenas ~2,3 pontos — estatisticamente pequena e com grande sobreposição.
#
# Conclusão para a direção:
# A qualidade da dieta, isoladamente, não demonstra impacto relevante na nota. A diferença entre os grupos é de menos de 3 pontos, e os intervalos de confiança se sobrepõem completamente. Se a escola precisar priorizar recursos, este não é o hábito que deve receber atenção imediata — hábitos como horas de estudo (impacto de +0,82) e saúde mental (+0,32) oferecem retorno muito maior.

# %% [markdown]
# **Maritaca.AI, Propt:"Alunos com trabalho de meio período (part_time_job) vão pior nas notas?" e resposta:**
# Gráfico 1 — Nota média comparativa
# ![image.png](attachment:image.png)
#
# Gráfico 2 — Distribuição completa das nota
# Os box:
# ![image-2.png](attachment:image-2.png)
#
#
# - Conclusão para a direção
# Não — alunos com trabalho de meio período não vão pior nas notas. A diferença de 1,1 ponto está dentro da margem de erro e não tem relevância prática. Isso sugere que os alunos que trabalham estão conseguindo gerenciar seu tempo sem sacrificar o desempenho, ou que quem consegue manter o emprego já é um aluno com boa organização.

# %% [markdown]
# **Chat GPT, Propt:"A escolaridade dos pais (parental_education_level) tem relação com o desempenho?" e resposta:**
#
# Média da nota por escolaridade dos pais:
#
# ![image.png](attachment:image.png)
#
# - Conclusão
# A escolaridade dos pais não apresenta uma relação forte com o desempenho dos alunos nesta base de dados. Embora estudantes cujos pais possuem graduação (Bachelor) tenham obtido a maior média, a diferença para os demais grupos é de apenas cerca de 2,2 pontos, indicando que essa variável, sozinha, explica pouco da variação nas notas.

# %% [markdown]
# **Chat GPT, Propt:"Existe uma quantidade ideal de horas de sono para tirar as melhores notas?" e resposta:**
#
# Horas de sono x Média da nota:
#
# ![image.png](attachment:image.png)
#
# Conclusão:
# O gráfico permite identificar a faixa de horas de sono associada às maiores médias. Caso a curva atinja seu ponto máximo entre 7 e 8 horas, pode-se concluir que essa é a quantidade de sono que apresenta o melhor desempenho acadêmico na base analisada. Dormir menos ou mais do que essa faixa tende a estar associado a notas ligeiramente menores.

# %% [markdown]
# **Chat GPT, Propt:"Existe uma quantidade ideal de horas de sono para tirar as melhores notas?" e resposta:**
#
# Horas de sono x Desempenho acadêmico:
#
# ![image.png](attachment:image.png)
#
# Análise - O gráfico mostra que a média das notas aumenta à medida que as horas de sono aumentam até aproximadamente 8 horas. Após esse ponto, observa-se uma leve redução na média das notas.
#
# Conclusão:
# Os dados indicam que dormir cerca de 7 a 8 horas por noite está associado ao melhor desempenho acadêmico. Alunos que dormem menos de 6 horas tendem a apresentar notas menores, enquanto dormir mais de 9 horas não demonstrou melhorar o desempenho. Como quase tudo envolvendo seres humanos, existe um ponto de equilíbrio. Dormir pouco cobra a conta, e dormir muito não faz a prova responder sozinha.

# %% [markdown]
#  ## **Cuidados e Ética no uso da IA**

# %% [markdown]
# ## **Parte3**

# %% [markdown]
# **Chat GPT, Propt:"Por que os alunos mais velhos desta base tiraram notas muito mais altas?" e resposta:**
#
# Idade x Média da nota:
#
# ![image.png](attachment:image.png)
#
# Análise - O gráfico indica que a média das notas aumenta conforme a idade dos alunos. Os estudantes mais velhos apresentaram desempenho superior aos mais novos.
#
# Conclusão:
# Nesta base de dados, observa-se uma relação positiva entre idade e desempenho acadêmico: quanto maior a idade, maior tende a ser a média das notas. Entretanto, isso não significa que a idade seja a causa direta das notas mais altas. O mais provável é que ela esteja associada a outros fatores que realmente influenciam o desempenho. Estatística adora esse tipo de armadilha: duas variáveis andam juntas e muita gente já declara um casamento de causa e efeito.

# %% [markdown]
# **Nesta etapa do trabalho, nós perguntamos para a inteligência artificial se a idade dos alunos tinha relação com as notas. A IA respondeu que os alunos mais velhos apresentavam notas mais altas e até criou uma explicação para esse resultado.**
#
# **Porém, ao conferir os dados no notebook, percebemos que não podemos confiar apenas na resposta da IA. Ela pode gerar informações que parecem corretas, mas que não são confirmadas pelos dados. Por isso, é fundamental validar todas as análises antes de utilizá-las em um relatório ou para tomar decisões.**
#
# **Esse exercício mostrou a importância da ética no uso da inteligência artificial. A IA é uma ferramenta que pode acelerar o trabalho e ajudar na interpretação dos dados, mas ela não substitui a análise crítica do profissional. Um bom analista sempre verifica os números, confere os gráficos e confirma se as conclusões realmente são sustentadas pelos dados antes de apresentá-las.**
