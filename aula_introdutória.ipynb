# %%
print("Treinamento de IA para Ánalise de Dados")
# Out:
# Treinamento de IA para Ánalise de Dados

# %%
print('Eduardo Godoy')
# Out:
# Eduardo Godoy

# %%
#Célula de váriaveis
nome = 'Eduardo Godoy'
print("O seu nome é",nome)
# Out:
# O seu nome é Eduardo Godoy

# %%
print(f'O seu nome é {nome}')
# Out:
# O seu nome é Eduardo Godoy

# %%
nome = 'Eduardo Godoy'
Idade = 17
Email = 'godoyeduardo135@gmail.com'
Profissao = 'Jovem Aprendiz'

print(f"O meu nome é {nome},eu tenho {Idade}, meu Email é {Email} e sou {Profissao}")
# Out:
# O meu nome é Eduardo Godoy,eu tenho 17 Anos, meu Email é godoyeduardo135@gmail.com e sou Jovem Aprendiz

# %%
#Comparadores
print(10>5)
# Out:
# True

# %%
#Comparadpr
comparador = 10 > 5 #Retorna true se for maior
print(comparador)
# Out:
# True

# %%
comparador = 5 < 10 #Retorna true se for menor
print(comparador)
# Out:
# True

# %%
comparador = (10 == 10) #Retorna true se forem iguais
print(comparador)
# Out:
# True

# %%
comparador = (10 != 5 ) #retorna True se forem diferentes 
print(comparador)
# Out:
# True

# %%
temperatura = 100
if temperatura > 100:
    print("Alarme! O Motor está fervendo")
else:
    print("Motor em temperatura Ideal")
# Out:
# Motor em temperatura Ideal

# %%
criar um Script, Que irá auxiliar os alunos do SENAI a saberem se devem ou não comprar um unifome. 
cursos acima de 40 horas, necessitam de uniforme.
Cursos abaixo de 40 horas, não necessitam de uniforme
- Power BI: 32 Horas
- IA e Ánalise de dados: 40 Horas 
- Eletrecista Predial: 160 Horas

# %%
power_bi= 32
ia_dados=40 
eletric_pred=160

# %%
if power_bi > 40:
    print("UNIFORME NECESSÁRIO")
else:
    print("CRACHÁ NECESSÁRIO")
# Out:
# CRACHÁ NECESSÁRIO

# %%
if ia_dados > 40:
    print("UNIFORME NECESSÁRIO")
else:
    print("CRACHÁ NECESSÁRIO")
# Out:
# CRACHÁ NECESSÁRIO

# %%
if eletric_pred > 160:
    print("UNIFORME NECESSÁRIO")
else:
    print("CRACHÁ NECESSÁRIO")
# Out:
# CRACHÁ NECESSÁRIO

# %%
#O comando input solicita a interação do usuário
nota = int(input)("Digite sua Nota: "))
print(nota)

# %%
Verificar a qualidade das notas de um aluno
MAIOR QUE 9: EXCELENTE

# %%
if nota >9:
    print("NOTA EXCELENTE") 
elif nota >7:
    print("NOTA BOA")
else:
    print("REPROVADO")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 if nota >9:
#       2     print("NOTA EXCELENTE")
#       3 elif nota >7:
#
# NameError: name 'nota' is not defined

# %%
#APP de um banco virtual
nome = input("Digite o seu nome:")
print(f"Bem vindo {nome}")
# Out:
# Bem vindo Eduardo

# %%
#Receber a idade da pessoa 
idade = int(input("digite a sua idade"))
print(idade)
print(type(idade))
# Out:
# 18
# <class 'int'>
