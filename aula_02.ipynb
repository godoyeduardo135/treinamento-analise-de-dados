# %%
#Estruturas de dados
temperaturas = [30,35,39,40,42,45,38,37]
print(temperaturas)
# Out:
# [30, 35, 39, 40, 42, 45, 38, 37]

# %%
print(temperaturas[1])
# Out:
# 35

# %%
print(temperaturas[7])
# Out:
# 37

# %%
print(f"o primeiro registro de temperatura foi de {temperaturas[0]} graus.")
# Out:
# o primeiro registro de temperatura foi de 30 graus.

# %%
temperaturas [0] = 35
print(temperaturas[0])
# Out:
# 35

# %%
print(f"o primeiro registro de temperatura foi de {temperaturas[0]} graus.")
# Out:
# o primeiro registro de temperatura foi de 35 graus.

# %%
temperaturas.append(50)
print(temperaturas)
# Out:
# [35, 35, 39, 40, 42, 45, 38, 37, 50]

# %%
temperaturas.remove(38)
print(temperaturas)
# Out:
# [35, 40, 42, 45, 37, 50]

# %%
temperaturas.remove(temperaturas[0])
print(temperaturas)
# Out:
# [40, 42, 45, 37, 50]

# %% [markdown]
# Criem uma lista e solicitem o usuario insira informação (3 comandos input). Ao finalizar, Exibir a lista de compras.

# %%
Item1 = input("Digite o Item1:")
lista_compras.append (Item1)
print(Item1)

Item2 = input("Digite o Item2:")
lista_compras.append(Item2)
print(Item2)

Item3 = input("Digite O Item3:")
lista_compras.append(Item3)
print(Item3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 2
#       1 Item1 = input("Digite o Item1:")
# ----> 2 lista_compras.append (Item1)
#       3 print(Item1)
#       5 Item2 = input("Digite o Item2:")
#
# NameError: name 'lista_compras' is not defined
