# %%
conceito de n-gramas
# Out:
#   Cell In[78], line 1
#     conceito de n-gramas
#              ^
# SyntaxError: invalid syntax

# %%
frase = "O amor é lindo o amor é forte o amor vence tudo"

# %%
palavras = frase.split()
palavras
# Out:
# ['O',
#  'amor',
#  'é',
#  'lindo',
#  'o',
#  'amor',
#  'é',
#  'forte',
#  'o',
#  'amor',
#  'vence',
#  'tudo']

# %%
import pandas as pd
tabela = pd.DataFrame({"palavra":palavras})
tabela
# Out:
#    palavra
# 0        O
# 1     amor
# 2        é
# 3    lindo
# 4        o
# 5     amor
# 6        é
# 7    forte
# 8        o
# 9     amor
# 10   vence
# 11    tudo

# %%
tabela["proxima_palavra"] = tabela["palavra"].shift(-1)
tabela
# Out:
#    palavra proxima_palavra
# 0        O            amor
# 1     amor               é
# 2        é           lindo
# 3    lindo               o
# 4        o            amor
# 5     amor               é
# 6        é           forte
# 7    forte               o
# 8        o            amor
# 9     amor           vence
# 10   vence            tudo
# 11    tudo             NaN

# %%
tabela = tabela.dropna()
tabela
# Out:
#    palavra proxima_palavra
# 0        O            amor
# 1     amor               é
# 2        é           lindo
# 3    lindo               o
# 4        o            amor
# 5     amor               é
# 6        é           forte
# 7    forte               o
# 8        o            amor
# 9     amor           vence
# 10   vence            tudo

# %%
filtro = tabela["palavra"] == "o"
tabela[filtro]
# Out:
#   palavra proxima_palavra
# 4       o            amor
# 8       o            amor

# %%
tabela[filtro]["proxima_palavra"].value_counts(normalize=True)
# Out:
# proxima_palavra
# amor    1.0
# Name: proportion, dtype: float64

# %%
tabela[filtro]["proxima_palavra"].value_counts().idxmax()
# Out:
# 'amor'
